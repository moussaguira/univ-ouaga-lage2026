# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
import flopy

# %%
cwd = os.getcwd()

# Create a 100x100 array of random integers from 0 to 15
data = np.random.randint(0, 16, size=(100, 100))

# Plot the array
plt.imshow(data, cmap='viridis', interpolation='nearest')
plt.colorbar(label='Value')
plt.title('100x100 Random Integer Grid (0–15)')
plt.show()
figname = os.path.join(cwd, '../figures/testfig.pdf')
plt.savefig(figname)

# %% [markdown]
# ## GitHub.com

# %%
import flopy

# Create a dictionary for stress periods 0 through 9 (1 through 10)
saverecord_dict = {}
for kper in range(10):  # 0 to 9 correspond to stress periods 1 to 10
  saverecord_dict[kper] = [("HEAD", "ALL"), ("BUDget", "ALL")]

# Optional print settings (e.g., print last step of each to listing file)
printrecord_dict = {kper: [("HEAD", "LAST")] for kper in range(10)}

# Initialize the Output Control package for Groundwater Flow (GWF)
oc = flopy.mf6.ModflowGwfoc(
    gwf,  # Assuming 'gwf' is your groundwater model instance
    pname="oc",
    head_filerecord=f"{gwf.name}.hds",
    budget_filerecord=f"{gwf.name}.cbc",
    saverecord=saverecord_dict,
    # printrecord=printrecord_dict,
)
